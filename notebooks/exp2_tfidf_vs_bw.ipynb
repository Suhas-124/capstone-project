# %%
import setuptools
import os
import re
import string
import pandas as pd
pd.set_option('future.no_silent_downcasting', True)

import numpy as np
import mlflow
import mlflow.sklearn
import dagshub
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import scipy.sparse

import warnings
warnings.simplefilter("ignore", UserWarning)
warnings.filterwarnings("ignore")

# ========================== CONFIGURATION ==========================
CONFIG = {
    "data_path": "data.csv",
    "test_size": 0.2,
    "mlflow_tracking_uri": "https://dagshub.com/Suhas-124/capstone-project.mlflow",
    "dagshub_repo_owner": "Suhas-124",
    "dagshub_repo_name": "capstone-project",
    "experiment_name": "Bow vs TfIdf"
}

# ========================== SETUP MLflow & DAGSHUB ==========================
mlflow.set_tracking_uri(CONFIG["mlflow_tracking_uri"])
dagshub.init(repo_owner=CONFIG["dagshub_repo_owner"], repo_name=CONFIG["dagshub_repo_name"], mlflow=True)
mlflow.set_experiment(CONFIG["experiment_name"])

# ========================== TEXT PREPROCESSING ==========================
def lemmatization(text):
    lemmatizer = WordNetLemmatizer()
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

def remove_stop_words(text):
    stop_words = set(stopwords.words("english"))
    return " ".join([word for word in text.split() if word not in stop_words])

def removing_numbers(text):
    return ''.join([char for char in text if not char.isdigit()])

def lower_case(text):
    return text.lower()

def removing_punctuations(text):
    return re.sub(f"[{re.escape(string.punctuation)}]", ' ', text)

def removing_urls(text):
    return re.sub(r'https?://\S+|www\.\S+', '', text)

def normalize_text(df):
    try:
        df['review'] = df['review'].apply(lower_case)
        df['review'] = df['review'].apply(remove_stop_words)
        df['review'] = df['review'].apply(removing_numbers)
        df['review'] = df['review'].apply(removing_punctuations)
        df['review'] = df['review'].apply(removing_urls)
        df['review'] = df['review'].apply(lemmatization)
        return df
    except Exception as e:
        print(f"Error during text normalization: {e}")
        raise

# ========================== LOAD & PREPROCESS DATA ==========================
def load_data(file_path):
    try:
        df = pd.read_csv(file_path)
        df = normalize_text(df)
        df = df[df['sentiment'].isin(['positive', 'negative'])]
        df['sentiment'] = df['sentiment'].replace({'negative': 0, 'positive': 1}).infer_objects(copy=False)
        return df
    except Exception as e:
        print(f"Error loading data: {e}")
        raise

# ========================== FEATURE ENGINEERING ==========================
VECTORIZERS = {
    'BoW': CountVectorizer(),
    'TF-IDF': TfidfVectorizer()
}

ALGORITHMS = {
    'LogisticRegression': LogisticRegression(),
    'MultinomialNB': MultinomialNB(),
    'XGBoost': XGBClassifier(),
    'RandomForest': RandomForestClassifier(),
    'GradientBoosting': GradientBoostingClassifier()
}

# ========================== TRAIN & EVALUATE MODELS ==========================
def train_and_evaluate(df):
    with mlflow.start_run(run_name="All Experiments") as parent_run:
        for algo_name, algorithm in ALGORITHMS.items():
            for vec_name, vectorizer in VECTORIZERS.items():
                with mlflow.start_run(run_name=f"{algo_name} with {vec_name}", nested=True) as child_run:
                    try:
                        # Feature extraction
                        X = vectorizer.fit_transform(df['review'])
                        y = df['sentiment']
                        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=CONFIG["test_size"], random_state=42)

                        # Log preprocessing parameters
                        mlflow.log_params({
                            "vectorizer": vec_name,
                            "algorithm": algo_name,
                            "test_size": CONFIG["test_size"]
                        })

                        # Train model
                        model = algorithm
                        model.fit(X_train, y_train)

                        # Log model parameters
                        log_model_params(algo_name, model)

                        # Evaluate model
                        y_pred = model.predict(X_test)
                        metrics = {
                            "accuracy": accuracy_score(y_test, y_pred),
                            "precision": precision_score(y_test, y_pred),
                            "recall": recall_score(y_test, y_pred),
                            "f1_score": f1_score(y_test, y_pred)
                        }
                        mlflow.log_metrics(metrics)

                        # Log model
                        # mlflow.sklearn.log_model(model, "model")
                        input_example = X_test[:5] if not scipy.sparse.issparse(X_test) else X_test[:5].toarray()
                        mlflow.sklearn.log_model(model, "model", input_example=input_example)

                        # Print results for verification
                        print(f"\nAlgorithm: {algo_name}, Vectorizer: {vec_name}")
                        print(f"Metrics: {metrics}")

                    except Exception as e:
                        print(f"Error in training {algo_name} with {vec_name}: {e}")
                        mlflow.log_param("error", str(e))

def log_model_params(algo_name, model):
    """Logs hyperparameters of the trained model to MLflow."""
    params_to_log = {}
    if algo_name == 'LogisticRegression':
        params_to_log["C"] = model.C
    elif algo_name == 'MultinomialNB':
        params_to_log["alpha"] = model.alpha
    elif algo_name == 'XGBoost':
        params_to_log["n_estimators"] = model.n_estimators
        params_to_log["learning_rate"] = model.learning_rate
    elif algo_name == 'RandomForest':
        params_to_log["n_estimators"] = model.n_estimators
        params_to_log["max_depth"] = model.max_depth
    elif algo_name == 'GradientBoosting':
        params_to_log["n_estimators"] = model.n_estimators
        params_to_log["learning_rate"] = model.learning_rate
        params_to_log["max_depth"] = model.max_depth

    mlflow.log_params(params_to_log)

# ========================== EXECUTION ==========================
if __name__ == "__main__":
    df = load_data(CONFIG["data_path"])
    train_and_evaluate(df)
# Out:
# Initialized MLflow to track repo "Suhas-124/capstone-project"
# Repository Suhas-124/capstone-project initialized!
# Algorithm: LogisticRegression, Vectorizer: BoW
# Metrics: {'accuracy': 0.8, 'precision': 0.74, 'recall': 0.8409090909090909, 'f1_score': 0.7872340425531915}
# 🏃 View run LogisticRegression with BoW at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1/runs/362977119db840299cec1aa6c030e029
# 🧪 View experiment at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1
#
# Algorithm: LogisticRegression, Vectorizer: TF-IDF
# Metrics: {'accuracy': 0.72, 'precision': 0.6142857142857143, 'recall': 0.9772727272727273, 'f1_score': 0.7543859649122807}
# 🏃 View run LogisticRegression with TF-IDF at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1/runs/96dabddec51d4048b574c88504116bf2
# 🧪 View experiment at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1
#
# Algorithm: MultinomialNB, Vectorizer: BoW
# Metrics: {'accuracy': 0.78, 'precision': 0.72, 'recall': 0.8181818181818182, 'f1_score': 0.7659574468085106}
# 🏃 View run MultinomialNB with BoW at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1/runs/529861ca8e4346d29b61e682b43e980d
# 🧪 View experiment at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1
#
# Algorithm: MultinomialNB, Vectorizer: TF-IDF
# Metrics: {'accuracy': 0.68, 'precision': 0.581081081081081, 'recall': 0.9772727272727273, 'f1_score': 0.7288135593220338}
# 🏃 View run MultinomialNB with TF-IDF at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1/runs/65767b5db1594ded9a7c8f61a5d8f354
# 🧪 View experiment at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1
#
# Algorithm: XGBoost, Vectorizer: BoW
# Metrics: {'accuracy': 0.72, 'precision': 0.6481481481481481, 'recall': 0.7954545454545454, 'f1_score': 0.7142857142857143}
# 🏃 View run XGBoost with BoW at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1/runs/d76aa6afc6544fb7889fa131b98f59d5
# 🧪 View experiment at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1
#
# Algorithm: XGBoost, Vectorizer: TF-IDF
# Metrics: {'accuracy': 0.69, 'precision': 0.6140350877192983, 'recall': 0.7954545454545454, 'f1_score': 0.693069306930693}
# 🏃 View run XGBoost with TF-IDF at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1/runs/7f49600e3780432a8b7979bb3b3c0bf4
# 🧪 View experiment at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1
#
# Algorithm: RandomForest, Vectorizer: BoW
# Metrics: {'accuracy': 0.68, 'precision': 0.59375, 'recall': 0.8636363636363636, 'f1_score': 0.7037037037037037}
# 🏃 View run RandomForest with BoW at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1/runs/c8ab35b5651440759e209e7fec309863
# 🧪 View experiment at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1
#
# Algorithm: RandomForest, Vectorizer: TF-IDF
# Metrics: {'accuracy': 0.67, 'precision': 0.582089552238806, 'recall': 0.8863636363636364, 'f1_score': 0.7027027027027027}
# 🏃 View run RandomForest with TF-IDF at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1/runs/381641c2da3f428a86dc6ae4c3d097a9
# 🧪 View experiment at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1
#
# Algorithm: GradientBoosting, Vectorizer: BoW
# Metrics: {'accuracy': 0.68, 'precision': 0.59375, 'recall': 0.8636363636363636, 'f1_score': 0.7037037037037037}
# 🏃 View run GradientBoosting with BoW at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1/runs/1cf5bb1efdaa41238a421532951a6eee
# 🧪 View experiment at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1
#
# Algorithm: GradientBoosting, Vectorizer: TF-IDF
# Metrics: {'accuracy': 0.67, 'precision': 0.5873015873015873, 'recall': 0.8409090909090909, 'f1_score': 0.6915887850467289}
# 🏃 View run GradientBoosting with TF-IDF at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1/runs/9cb10786afd44e7e93b95b8cc69b25d6
# 🧪 View experiment at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1
# 🏃 View run All Experiments at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1/runs/de2a16db046b452bb0c3884e046feaaf
# 🧪 View experiment at: https://dagshub.com/Suhas-124/capstone-project.mlflow/#/experiments/1
